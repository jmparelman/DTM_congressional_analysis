# %% [markdown]
# # Comparing Topic Models with Parties Together and Apart

# %% [markdown]
# There are two potential approaches for modeling Democrat and Republic language in the congressional record and comparing the frames employed by the two parties on specific issues. The first approach is to model all speeches by the two parties together, and then separate the corpus by party after labelling speeches with their most likely topic. A comparison of the top terms can then be done between the two parties.
#
# The alternative approach is to model the two parties as separate corpora, each with their own topics and term distributions.
#
# In this noteobok, a comparison of the terms returned by these two methods is performed. If the two methods return similar results across three congresses (112,113,114), I will take the less laborious method as the standard for this dissertation research (e.g. parties together).
#
# The number of topics for each model were selected from evaluations performed in `evaluations.ipynb`

# %%
import pandas as pd
import numpy as np
from operator import itemgetter
import boto3
from gensim.models import Nmf,TfidfModel,CoherenceModel
from gensim.corpora import Dictionary
from nltk import Counter

# %run ../model_developer.py
client= boto3.client('s3')

procedural_stop_words.extend(['be','have','do','go'])
# Out:
# loaded model_developer.py

# %% [markdown]
# ## 112th congress

# %% [markdown]
# ### Together

# %%
_112th = pd.read_csv(client.get_object(Bucket='ascsagemaker',Key='JMP_congressional_nmf/House_bigrams/112.csv')['Body'])
_112th = _112th.loc[_112th.chamber_x == 'H']

# %% [markdown]
# generate corpus for fitting

# %%
speeches = [[word for word in speech.split() if word not in procedural_stop_words] for speech in _112th.speech_processed]
dictionary = gensim.corpora.Dictionary(speeches)
dictionary.filter_extremes(no_below=0.001*len(speeches),no_above=.35)
corpus = [dictionary.doc2bow(text) for text in speeches]
model = TfidfModel(corpus)
tfidf = [model[i] for i in corpus]

model = Nmf(corpus = tfidf,
                    id2word = dictionary,
                    num_topics = 30,
                    random_state = np.random.randint(1,1000),
                    normalize = True,
                    passes = 20)

coh_model = CoherenceModel(model = model,
                           texts=speeches,
                           dictionary = dictionary,
                           coherence='c_v',
                           processes=1)

print(coh_model.get_coherence())
# Out:
# 0.6071394931611472

# %%
for i in range(30):
    print(model.print_topic(i),end='\n\n')
# Out:
# 0.073*"budget" + 0.023*"senior" + 0.019*"republican" + 0.017*"medicare" + 0.012*"plan" + 0.011*"end_medicare" + 0.010*"social_security" + 0.009*"pay" + 0.009*"tax_break" + 0.008*"deficit"
#
# 0.044*"epa" + 0.015*"clean_air" + 0.012*"standard" + 0.011*"health" + 0.010*"mercury" + 0.009*"pollution" + 0.009*"water" + 0.009*"emission" + 0.007*"state" + 0.007*"clean_water"
#
# 0.032*"energy" + 0.031*"oil" + 0.012*"pipeline" + 0.011*"price" + 0.010*"drill" + 0.010*"natural_gas" + 0.008*"gas_price" + 0.008*"keystone_pipeline" + 0.008*"production" + 0.006*"drilling"
#
# 0.025*"insurance" + 0.024*"pay" + 0.022*"tax" + 0.022*"health_insurance" + 0.016*"health_care" + 0.013*"coverage" + 0.013*"percent" + 0.012*"obamacare" + 0.011*"taxis" + 0.011*"premium"
#
# 0.044*"veteran" + 0.012*"serve" + 0.011*"military" + 0.010*"service" + 0.009*"honor" + 0.006*"va" + 0.006*"sacrifice" + 0.006*"man_woman" + 0.005*"return" + 0.005*"army"
#
# 0.046*"resolution" + 0.038*"war" + 0.028*"libya" + 0.015*"president" + 0.013*"power" + 0.011*"military" + 0.008*"afghanistan" + 0.008*"nato" + 0.007*"pursuant_house" + 0.007*"congress"
#
# 0.027*"israel" + 0.017*"iran" + 0.008*"world" + 0.008*"peace" + 0.008*"palestinian" + 0.007*"america" + 0.006*"u" + 0.006*"nuclear_weapon" + 0.006*"united_state" + 0.006*"nation"
#
# 0.041*"republican" + 0.016*"job" + 0.014*"president" + 0.013*"middle_class" + 0.013*"plan" + 0.010*"house" + 0.010*"tax_cut" + 0.008*"economy" + 0.007*"democrat" + 0.006*"leadership"
#
# 0.077*"abortion" + 0.027*"woman" + 0.027*"plan_parenthood" + 0.015*"life" + 0.011*"funding_abortion" + 0.010*"fund" + 0.009*"hyde_amendment" + 0.008*"federal" + 0.008*"baby" + 0.008*"right"
#
# 0.069*"program" + 0.013*"homeowner" + 0.011*"loan" + 0.009*"mortgage" + 0.008*"fund" + 0.008*"taxpayer" + 0.007*"help" + 0.007*"tax" + 0.007*"money" + 0.007*"flood_insurance"
#
# 0.046*"job" + 0.021*"agreement" + 0.018*"create_job" + 0.015*"trade" + 0.013*"export" + 0.012*"create" + 0.010*"america" + 0.009*"free_trade" + 0.009*"company" + 0.009*"trade_agreement"
#
# 0.058*"woman" + 0.034*"madam_speaker" + 0.014*"victim" + 0.014*"domestic_violence" + 0.012*"violence_woman" + 0.010*"violence" + 0.009*"house" + 0.008*"yield" + 0.007*"vawa" + 0.007*"protection"
#
# 0.040*"care" + 0.026*"health" + 0.026*"senior" + 0.018*"medical" + 0.016*"patient" + 0.015*"doctor" + 0.013*"hospital" + 0.012*"physician" + 0.011*"access" + 0.010*"center"
#
# 0.033*"constitution" + 0.030*"balanced_budget" + 0.012*"congress" + 0.011*"government" + 0.011*"right" + 0.011*"power" + 0.009*"united_state" + 0.008*"balance_budget" + 0.007*"constitutional" + 0.006*"debt"
#
# 0.078*"cut" + 0.023*"spending" + 0.011*"deficit" + 0.010*"percent" + 0.009*"revenue" + 0.008*"tax_cut" + 0.008*"defense" + 0.007*"reduce_deficit" + 0.006*"social_security" + 0.006*"sequestration"
#
# 0.075*"medicare" + 0.057*"health_care" + 0.024*"senior" + 0.018*"cost" + 0.013*"reform" + 0.011*"obamacare" + 0.011*"plan" + 0.011*"ipab" + 0.009*"system" + 0.009*"doctor"
#
# 0.035*"spending" + 0.021*"state" + 0.020*"debt" + 0.014*"washington" + 0.014*"spend" + 0.010*"federal" + 0.010*"federal_government" + 0.008*"budget" + 0.008*"increase" + 0.008*"problem"
#
# 0.048*"repeal" + 0.033*"provision" + 0.027*"law" + 0.020*"health_care" + 0.018*"act" + 0.016*"affordable_care" + 0.016*"reform" + 0.010*"patriot_act" + 0.009*"coverage" + 0.005*"insurance_company"
#
# 0.024*"child" + 0.011*"family" + 0.010*"community" + 0.009*"food" + 0.006*"life" + 0.005*"home" + 0.005*"district" + 0.005*"county" + 0.005*"help" + 0.004*"city"
#
# 0.096*"dollar_amount" + 0.068*"page_line" + 0.051*"follow_page" + 0.048*"insert_reduce" + 0.048*"recognize_minute" + 0.026*"line" + 0.021*"insert_follow" + 0.018*"short_title" + 0.017*"sec_none" + 0.016*"increase"
#
# 0.048*"student" + 0.042*"school" + 0.027*"education" + 0.018*"charter_school" + 0.014*"student_loan" + 0.013*"college" + 0.011*"teacher" + 0.011*"interest_rate" + 0.008*"public" + 0.007*"high_school"
#
# 0.078*"vote" + 0.024*"present" + 0.012*"house" + 0.010*"miss" + 0.010*"previous_question" + 0.010*"question" + 0.008*"voter" + 0.008*"detain" + 0.008*"election" + 0.008*"record"
#
# 0.085*"small_business" + 0.022*"business" + 0.016*"owner" + 0.015*"tax" + 0.011*"job_creator" + 0.010*"hire" + 0.008*"taxis" + 0.008*"economy" + 0.008*"entrepreneur" + 0.008*"create_job"
#
# 0.095*"regulation" + 0.018*"regulatory" + 0.015*"cost" + 0.009*"agency" + 0.009*"business" + 0.008*"new" + 0.007*"economy" + 0.006*"job_creator" + 0.006*"impact" + 0.006*"rein"
#
# 0.022*"research" + 0.014*"energy" + 0.014*"technology" + 0.012*"investment" + 0.012*"transportation" + 0.010*"project" + 0.009*"infrastructure" + 0.008*"innovation" + 0.007*"invest" + 0.006*"manufacturing"
#
# 0.012*"gabby" + 0.010*"arizona" + 0.009*"water" + 0.008*"tragedy" + 0.007*"life" + 0.007*"constituent" + 0.007*"victim" + 0.006*"staff" + 0.006*"gabby_gifford" + 0.006*"pray"
#
# 0.013*"dont" + 0.011*"that" + 0.010*"know" + 0.009*"come" + 0.009*"money" + 0.007*"try" + 0.007*"theyre" + 0.007*"let" + 0.007*"look" + 0.006*"see"
#
# 0.061*"worker" + 0.024*"union" + 0.018*"right" + 0.015*"employer" + 0.011*"employee" + 0.010*"wage" + 0.010*"labor" + 0.010*"election" + 0.008*"national_labor" + 0.008*"workforce"
#
# 0.016*"afghanistan" + 0.014*"funding" + 0.014*"security" + 0.014*"fund" + 0.009*"troop" + 0.008*"military" + 0.007*"defense" + 0.006*"fiscal_year" + 0.006*"afghan" + 0.005*"request"
#
# 0.008*"information" + 0.006*"agency" + 0.005*"require" + 0.005*"report" + 0.005*"land" + 0.004*"federal" + 0.004*"state" + 0.003*"authority" + 0.003*"company" + 0.003*"issue"

# %%
Together_Topics = ["Budget", "Environment",'Energy',"Health_care",'Veterans',"Defense_conflict",'International_Affairs',
'Macroeconomics',"Abortion",'Domestic_commerce','Labor',"Law_and_Crime","Health_care",
'Budget',"Budget_deficit",'Health_care','Budget','Health_care','Social_welfare',
'Procedural','Higher_education','Procedural','Small_business','Domestic_commerce_regulation',
'Research_technology','Tribute','NA','Labor','Defense_spending','Defense_intelligence']

# %%
doc_topics = model.get_document_topics(tfidf,minimum_probability=None)

# %%
_112th['Topic'] = [Together_Topics[max(i,key=lambda item:item[1])[0]] for i in doc_topics]

# %%
_112th['Topic']
# Out:
# 5               Macroeconomics
# 6        International_Affairs
# 7         Defense_intelligence
# 8                       Budget
# 9                           NA
#                  ...
# 45658               Procedural
# 45659                       NA
# 45660                   Budget
# 45661         Defense_conflict
# 45662     Defense_intelligence
# Name: Topic, Length: 29783, dtype: object

# %%
def top_terms(x):
    speech = [[word for word in sp.split() if word not in procedural_stop_words] for sp in x]
    sorted_count = Counter([term for sublist in speech for term in sublist])
    top_terms = [i[0] for i in sorted_count.most_common()[:20]]
    return top_terms

# %%
Together_Terms = _112th.groupby(['Topic','party']).speech_processed.apply(top_terms).reset_index().pivot(index='Topic',columns=['party'])

# %%
Together_Terms
# Out:
#                                                                speech_processed  \
# party                                                                         D
# Topic
# Abortion                      [woman, abortion, service, health_care, plan_p...
# Budget                        [budget, republican, american, people, say, cu...
# Budget_deficit                [cut, people, job, make, spending, say, republ...
# Defense_conflict              [war, resolution, congress, libya, president, ...
# Defense_intelligence          [time, state, make, support, act, work, americ...
# Defense_spending              [afghanistan, time, security, support, need, p...
# Domestic_commerce             [program, help, people, homeowner, home, time,...
# Domestic_commerce_regulation  [regulation, american, job, time, congress, pe...
# Energy                        [oil, energy, american, say, time, year, job, ...
# Environment                   [epa, act, health, state, clean_air, time, sta...
# Health_care                   [health_care, medicare, people, senior, americ...
# Higher_education              [student, school, education, program, student_...
# International_Affairs         [israel, iran, united_state, people, support, ...
# Labor                         [job, american, worker, work, people, america,...
# Law_and_Crime                 [woman, act, victim, republican, year, domesti...
# Macroeconomics                [republican, american, job, people, house, wor...
# NA                            [people, say, get, want, know, dont, time, wor...
# Procedural                    [vote, mr_speaker, people, american, time, hou...
# Research_technology           [make, need, america, job, american, investmen...
# Small_business                [small_business, business, job, percent, ameri...
# Social_welfare                [child, people, family, american, year, progra...
# Tribute                       [people, time, work, water, congress, state, k...
# Veterans                      [veteran, service, serve, military, american, ...
#
#
# party                                                                         R
# Topic
# Abortion                      [abortion, plan_parenthood, woman, life, say, ...
# Budget                        [budget, spending, people, american, say, cong...
# Budget_deficit                [cut, spending, budget, people, make, say, ame...
# Defense_conflict              [war, resolution, president, libya, congress, ...
# Defense_intelligence          [time, state, act, support, make, work, say, c...
# Defense_spending              [time, fund, funding, support, security, need,...
# Domestic_commerce             [program, time, say, need, people, fund, work,...
# Domestic_commerce_regulation  [regulation, job, cost, business, new, say, am...
# Energy                        [energy, oil, american, job, say, country, get...
# Environment                   [epa, job, regulation, state, say, act, time, ...
# Health_care                   [health_care, medicare, american, people, law,...
# Higher_education              [student, school, education, program, charter_...
# International_Affairs         [people, israel, say, iran, united_state, pres...
# Labor                         [job, american, worker, work, agreement, time,...
# Law_and_Crime                 [woman, madam_speaker, work, victim, say, hous...
# Macroeconomics                [republican, job, american, house, people, pre...
# NA                            [say, people, get, know, want, that, come, tim...
# Procedural                    [vote, page_line, house, voter, dollar_amount,...
# Research_technology           [program, research, energy, time, need, projec...
# Small_business                [small_business, business, job, american, more...
# Social_welfare                [child, people, family, year, work, american, ...
# Tribute                       [people, life, know, time, say, year, mr_speak...
# Veterans                      [veteran, serve, service, mr_speaker, time, ho...

# %%
def keyness(corpusA,corpusB):
    rowsD = pd.DataFrame([{"term":i,"corpus_a":k} for i,k in corpusA.items()])
    rowsR = pd.DataFrame([{"term":i,"corpus_b":k} for i,k in corpusB.items()])

    rows = rowsD.merge(rowsR,on='term',how='outer').fillna(0)
    rows.columns = ['term','freqA','freqB']

    rows['tot_1'] = sum([i for i in D.values()])
    rows['tot_2'] = sum([i for i in R.values()])

    rows['prob_A'] = rows['freqA']/rows['tot_1']
    rows['odds_A'] = rows['prob_A']/(1 - rows['prob_A'])

    rows['prob_B'] = rows['freqB']/rows['tot_2']
    rows['odds_B'] = rows['prob_B']/(1 - rows['prob_B'])

    rows['log_odds'] = np.log(rows['odds_A']/rows['odds_B'])
    rows.loc[rows.log_odds == -np.inf,'log_odds'] = -1
    rows.loc[rows.log_odds == np.inf,'log_odds'] = 1
    return rows.sort_values(by='log_odds',ascending=False)[['term','log_odds']]

# %%
def get_keyness(topic):
    D = _112th.loc[(_112th.party == "D") & (_112th.Topic == topic),'speech_processed'].values
    D = [[word for word in sp.split() if word not in procedural_stop_words] for sp in D]
    D = Counter([term for sublist in D for term in sublist])

    R = _112th.loc[(_112th.party == "R") & (_112th.Topic == topic),'speech_processed'].values
    R = [[word for word in sp.split() if word not in procedural_stop_words] for sp in R]
    R = Counter([term for sublist in R for term in sublist])
    

    key = keyness(D,R)
    key = key.sort_values(by='log_odds',ascending=False)
    Terms = key.head(10)
    Terms.columns = ['Dem_Term','Dem_val']

    Rep_terms = key.tail(10)
    Rep_terms = Rep_terms.sort_values(by='log_odds')

    Terms['Rep_Term'] = Rep_terms['term'].values
    Terms['Rep_val'] = Rep_terms['log_odds'].values
    return Terms

# %%
get_keyness('Abortion')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  Dem_Term   Dem_val           Rep_Term   Rep_val
# 345   reproductive_health  3.686374           innocent -3.747331
# 1185       small_business  3.435056              heart -3.229379
# 71              screening  3.098589               poll -3.193011
# 321             proponent  2.741901  abortion_provider -3.174330
# 447               limited  2.667793          obamacare -3.095857
# 2607            viability  2.667793              month -2.941694
# 261               propose  2.587750                god -2.892903
# 1969           preference  2.587750             little -2.841618
# 668         breast_cancer  2.454222       sexselection -2.841618
# 469            antichoice  2.405432       unborn_child -2.787572

# %% [markdown]
# ## Splitting Dem Rep

# %% [markdown]
# ### Dem

# %%
_112th_D = _112th.loc[_112th.party == 'D']
_112th_R = _112th.loc[_112th.party == 'R']

# %%
D_speeches = [[word for word in speech.split() if word not in procedural_stop_words] for speech in _112th_D.speech_processed]
D_dictionary = gensim.corpora.Dictionary(D_speeches)
D_dictionary.filter_extremes(no_below=0.001*len(D_speeches),no_above=.35)
D_corpus = [D_dictionary.doc2bow(text) for text in D_speeches]
D_model = TfidfModel(D_corpus)
D_tfidf = [D_model[i] for i in D_corpus]

D_model = Nmf(corpus = D_tfidf,
                    id2word = D_dictionary,
                    num_topics = 30,
                    random_state = np.random.randint(1,1000),
                    normalize = True,
                    passes = 20)

coh_model = CoherenceModel(model = D_model,
                           texts=D_speeches,
                           dictionary = D_dictionary,
                           coherence='c_v',
                           processes=1)

print(coh_model.get_coherence())
# Out:
# 0.5835307016416285

# %%
for i in range(30):
    print(D_model.print_topic(i),end='\n\n')
# Out:
# 0.092*"health_care" + 0.043*"reform" + 0.034*"repeal" + 0.011*"medicare" + 0.010*"affordable" + 0.010*"system" + 0.009*"insurance_company" + 0.007*"deficit" + 0.007*"obamacare" + 0.006*"patient"
#
# 0.029*"republican" + 0.021*"vote" + 0.013*"house" + 0.011*"let" + 0.009*"tax_cut" + 0.007*"middle_class" + 0.007*"friend" + 0.007*"dont" + 0.007*"bring" + 0.007*"get"
#
# 0.051*"worker" + 0.020*"union" + 0.017*"right" + 0.010*"labor" + 0.009*"trade" + 0.008*"employer" + 0.008*"wage" + 0.008*"colombia" + 0.008*"national_labor" + 0.008*"employee"
#
# 0.083*"veteran" + 0.013*"present" + 0.010*"va" + 0.010*"vote" + 0.009*"service" + 0.009*"return" + 0.008*"military" + 0.007*"serve" + 0.007*"veteran_affair" + 0.007*"miss"
#
# 0.024*"food" + 0.014*"dont" + 0.013*"get" + 0.010*"know" + 0.009*"that" + 0.008*"theyre" + 0.008*"youre" + 0.008*"cut" + 0.007*"lot" + 0.007*"come"
#
# 0.087*"woman" + 0.016*"domestic_violence" + 0.015*"victim" + 0.014*"violence_woman" + 0.011*"violence" + 0.011*"protection" + 0.010*"immigrant" + 0.009*"women" + 0.009*"vawa" + 0.008*"women_health"
#
# 0.068*"small_business" + 0.019*"business" + 0.009*"tax_credit" + 0.009*"america" + 0.008*"middle_class" + 0.008*"economy" + 0.007*"hire" + 0.007*"regulation" + 0.007*"entrepreneur" + 0.007*"employee"
#
# 0.050*"cut" + 0.033*"spending" + 0.019*"deficit" + 0.009*"revenue" + 0.009*"reduce_deficit" + 0.008*"investment" + 0.008*"tax_cut" + 0.007*"middle_class" + 0.007*"balanced_budget" + 0.007*"economy"
#
# 0.010*"agreement" + 0.008*"transportation" + 0.006*"issue" + 0.005*"provision" + 0.005*"support" + 0.005*"bipartisan" + 0.005*"important" + 0.004*"hope" + 0.004*"move" + 0.004*"safety"
#
# 0.034*"tax" + 0.032*"pay" + 0.018*"taxis" + 0.014*"percent" + 0.014*"tax_cut" + 0.011*"money" + 0.009*"income" + 0.009*"increase" + 0.009*"wealthy" + 0.009*"revenue"
#
# 0.049*"program" + 0.028*"homeowner" + 0.019*"home" + 0.019*"mortgage" + 0.017*"help" + 0.016*"foreclosure" + 0.011*"loan" + 0.010*"family" + 0.008*"modification" + 0.008*"housing"
#
# 0.060*"job" + 0.013*"america" + 0.013*"create_job" + 0.012*"lose" + 0.011*"create" + 0.010*"infrastructure" + 0.010*"economy" + 0.009*"manufacturing" + 0.008*"unemployment" + 0.007*"unemployed"
#
# 0.047*"child" + 0.015*"family" + 0.008*"parent" + 0.008*"yield" + 0.007*"young" + 0.007*"second" + 0.005*"life" + 0.005*"care" + 0.005*"many" + 0.005*"school"
#
# 0.064*"medicare" + 0.062*"senior" + 0.013*"benefit" + 0.012*"social_security" + 0.011*"middle_class" + 0.010*"end_medicare" + 0.008*"pay" + 0.007*"prescription_drug" + 0.007*"guarantee" + 0.006*"doughnut_hole"
#
# 0.096*"budget" + 0.021*"republican" + 0.018*"medicare" + 0.016*"plan" + 0.013*"end_medicare" + 0.011*"social_security" + 0.010*"medicaid" + 0.009*"senior" + 0.008*"tax_break" + 0.007*"value"
#
# 0.032*"health" + 0.019*"peace_corps" + 0.019*"public_broadcasting" + 0.018*"republican" + 0.014*"volunteer" + 0.012*"npr" + 0.012*"funding" + 0.011*"station" + 0.011*"center" + 0.010*"public_radio"
#
# 0.056*"resolution" + 0.038*"page_line" + 0.034*"dollar_amount" + 0.031*"follow_page" + 0.020*"pursuant_house" + 0.014*"insert_reduce" + 0.014*"recognize_minute" + 0.013*"gentlewoman_california" + 0.012*"strike" + 0.012*"line"
#
# 0.032*"affordable_care" + 0.029*"insurance" + 0.025*"health_insurance" + 0.024*"coverage" + 0.024*"repeal" + 0.019*"act" + 0.017*"law" + 0.015*"insurance_company" + 0.010*"exchange" + 0.010*"preexisting_condition"
#
# 0.014*"state" + 0.010*"land" + 0.010*"water" + 0.007*"local" + 0.007*"federal" + 0.006*"program" + 0.006*"funding" + 0.006*"area" + 0.005*"project" + 0.005*"fund"
#
# 0.030*"debt" + 0.028*"student_loan" + 0.025*"president" + 0.022*"interest_rate" + 0.017*"loan" + 0.008*"congress" + 0.007*"double" + 0.007*"college" + 0.007*"rate" + 0.007*"pay"
#
# 0.029*"constitution" + 0.013*"law" + 0.010*"right" + 0.010*"congress" + 0.009*"power" + 0.009*"united_state" + 0.007*"constitutional" + 0.007*"state" + 0.007*"balanced_budget" + 0.007*"court"
#
# 0.025*"epa" + 0.024*"regulation" + 0.015*"clean_air" + 0.011*"pollution" + 0.010*"mercury" + 0.010*"health" + 0.010*"standard" + 0.007*"emission" + 0.007*"act" + 0.006*"agency"
#
# 0.055*"cost" + 0.023*"care" + 0.020*"plan" + 0.014*"health_care" + 0.013*"senior" + 0.013*"longterm" + 0.013*"medicaid" + 0.012*"price" + 0.011*"subsidy" + 0.009*"taxpayer"
#
# 0.048*"abortion" + 0.019*"plan_parenthood" + 0.016*"service" + 0.015*"woman" + 0.014*"health" + 0.013*"care" + 0.011*"women_health" + 0.010*"medical" + 0.010*"family_planning" + 0.010*"access"
#
# 0.022*"global_war" + 0.021*"september_11th" + 0.021*"conclusion_bless" + 0.021*"troop_forget" + 0.020*"terrorism" + 0.015*"president" + 0.012*"house" + 0.012*"policy" + 0.012*"liberal" + 0.011*"vote"
#
# 0.026*"election" + 0.015*"voter" + 0.011*"campaign" + 0.008*"democracy" + 0.008*"money" + 0.006*"political" + 0.006*"vote" + 0.006*"information" + 0.006*"disclosure" + 0.006*"system"
#
# 0.041*"student" + 0.037*"school" + 0.024*"education" + 0.013*"teacher" + 0.012*"college" + 0.010*"charter_school" + 0.008*"student_loan" + 0.007*"interest_rate" + 0.007*"investment" + 0.007*"public"
#
# 0.025*"oil" + 0.023*"energy" + 0.010*"industry" + 0.009*"natural_gas" + 0.008*"drill" + 0.007*"price" + 0.006*"technology" + 0.006*"pipeline" + 0.006*"drilling" + 0.006*"america"
#
# 0.026*"afghanistan" + 0.024*"war" + 0.018*"military" + 0.012*"troop" + 0.008*"u" + 0.008*"afghan" + 0.007*"libya" + 0.007*"security" + 0.005*"iran" + 0.005*"war_afghanistan"
#
# 0.009*"honor" + 0.008*"serve" + 0.006*"life" + 0.006*"gabby" + 0.005*"service" + 0.004*"victim" + 0.004*"community" + 0.004*"tragedy" + 0.004*"great" + 0.004*"constituent"

# %%
R_speeches = [[word for word in speech.split() if word not in procedural_stop_words] for speech in _112th_R.speech_processed]
R_dictionary = gensim.corpora.Dictionary(R_speeches)
R_dictionary.filter_extremes(no_below=0.001*len(R_speeches),no_above=.35)
R_corpus = [R_dictionary.doc2bow(text) for text in R_speeches]
R_model = TfidfModel(R_corpus)
R_tfidf = [R_model[i] for i in R_corpus]

R_model = Nmf(corpus = R_tfidf,
                    id2word = R_dictionary,
                    num_topics = 30,
                    random_state = np.random.randint(1,1000),
                    normalize = True,
                    passes = 20)

coh_model = CoherenceModel(model = R_model,
                           texts=R_speeches,
                           dictionary = R_dictionary,
                           coherence='c_v',
                           processes=1)

print(coh_model.get_coherence())
# Out:
# 0.5326478397390679

# %%
for i in range(30):
    print(R_model.print_topic(i),end='\n\n')
# Out:
# 0.061*"health_care" + 0.021*"repeal" + 0.018*"law" + 0.018*"obamacare" + 0.015*"cost" + 0.012*"patient" + 0.011*"reform" + 0.010*"care" + 0.010*"doctor" + 0.010*"insurance"
#
# 0.050*"balanced_budget" + 0.028*"debt" + 0.018*"budget" + 0.014*"balance_budget" + 0.012*"balance" + 0.009*"constitution" + 0.009*"deficit" + 0.009*"live_mean" + 0.008*"national_debt" + 0.008*"congress"
#
# 0.056*"cut" + 0.021*"funding" + 0.015*"percent" + 0.014*"fiscal_year" + 0.013*"defense" + 0.013*"account" + 0.013*"level" + 0.012*"budget" + 0.011*"reduce" + 0.010*"reduction"
#
# 0.036*"border" + 0.012*"mexico" + 0.008*"arizona" + 0.008*"border_patrol" + 0.007*"security" + 0.007*"yucca_mountain" + 0.006*"law_enforcement" + 0.006*"agent" + 0.006*"new_york" + 0.006*"texas"
#
# 0.036*"job" + 0.015*"create_job" + 0.011*"business" + 0.011*"agreement" + 0.011*"create" + 0.010*"economy" + 0.010*"export" + 0.008*"america" + 0.008*"job_creator" + 0.007*"company"
#
# 0.083*"small_business" + 0.020*"owner" + 0.018*"business" + 0.009*"job_creator" + 0.009*"hire" + 0.008*"regulation" + 0.008*"employee" + 0.007*"grow" + 0.006*"entrepreneur" + 0.006*"burden"
#
# 0.031*"short_title" + 0.031*"sec_none" + 0.029*"insert_follow" + 0.027*"fund" + 0.025*"available" + 0.024*"act" + 0.018*"title" + 0.016*"code" + 0.015*"end" + 0.014*"use"
#
# 0.015*"state" + 0.014*"law" + 0.011*"provision" + 0.006*"federal" + 0.005*"permit" + 0.005*"information" + 0.005*"court" + 0.005*"require" + 0.004*"patent" + 0.004*"right"
#
# 0.091*"veteran" + 0.018*"va" + 0.010*"veteran_affair" + 0.007*"military" + 0.007*"benefit" + 0.007*"compensation" + 0.006*"service" + 0.006*"disability" + 0.006*"return" + 0.006*"facility"
#
# 0.007*"great" + 0.006*"america" + 0.006*"come" + 0.006*"know" + 0.005*"country" + 0.005*"texas" + 0.005*"world" + 0.005*"state" + 0.005*"see" + 0.004*"man"
#
# 0.031*"budget" + 0.015*"friend" + 0.009*"know" + 0.008*"house" + 0.008*"other_side" + 0.008*"weve" + 0.007*"yield" + 0.007*"try" + 0.007*"that" + 0.007*"folk"
#
# 0.050*"spending" + 0.015*"washington" + 0.013*"spend" + 0.013*"debt" + 0.010*"cut" + 0.010*"government" + 0.009*"deficit" + 0.009*"problem" + 0.008*"plan" + 0.008*"increase"
#
# 0.228*"dollar_amount" + 0.126*"insert_reduce" + 0.124*"page_line" + 0.093*"recognize_minute" + 0.091*"follow_page" + 0.054*"line" + 0.037*"increase" + 0.015*"gentleman_california" + 0.009*"line_insert" + 0.009*"gentleman_georgia"
#
# 0.015*"worker" + 0.014*"right" + 0.010*"victim" + 0.008*"attack" + 0.008*"gabby" + 0.008*"tsa" + 0.007*"airport" + 0.007*"day" + 0.006*"union" + 0.006*"employer"
#
# 0.048*"epa" + 0.015*"regulation" + 0.010*"clean_air" + 0.010*"standard" + 0.008*"industry" + 0.008*"permit" + 0.007*"water" + 0.007*"regulate" + 0.007*"health" + 0.006*"coal_ash"
#
# 0.084*"abortion" + 0.031*"plan_parenthood" + 0.014*"life" + 0.013*"funding_abortion" + 0.012*"taxpayer" + 0.011*"baby" + 0.010*"fund" + 0.009*"unborn_child" + 0.008*"hyde_amendment" + 0.008*"prolife"
#
# 0.059*"vote" + 0.015*"house" + 0.010*"present" + 0.008*"voter" + 0.007*"legislative" + 0.006*"republican" + 0.006*"unable" + 0.006*"noon" + 0.006*"election" + 0.005*"question"
#
# 0.041*"resolution" + 0.041*"madam_speaker" + 0.023*"purpose" + 0.021*"consideration" + 0.017*"house" + 0.014*"yield" + 0.014*"yield_customary" + 0.013*"report" + 0.011*"pursuant_house" + 0.011*"whole"
#
# 0.024*"constitution" + 0.020*"government" + 0.015*"energy" + 0.014*"power" + 0.009*"right" + 0.008*"federal_government" + 0.007*"liberty" + 0.006*"congress" + 0.006*"cost" + 0.005*"price"
#
# 0.069*"program" + 0.012*"fund" + 0.010*"funding" + 0.007*"grant" + 0.006*"taxpayer" + 0.006*"flood_insurance" + 0.006*"homeowner" + 0.006*"loan" + 0.005*"eliminate" + 0.005*"money"
#
# 0.014*"serve" + 0.013*"honor" + 0.010*"service" + 0.009*"life" + 0.007*"sergeant" + 0.007*"family" + 0.006*"army" + 0.006*"officer" + 0.005*"marine" + 0.005*"hero"
#
# 0.023*"money" + 0.015*"dont" + 0.012*"that" + 0.010*"pay" + 0.010*"theyre" + 0.009*"spend" + 0.008*"more" + 0.007*"lot" + 0.007*"youre" + 0.007*"problem"
#
# 0.072*"tax" + 0.020*"taxis" + 0.015*"tax_code" + 0.012*"increase" + 0.009*"reform" + 0.009*"pay" + 0.009*"medical_device" + 0.009*"fair" + 0.008*"percent" + 0.007*"rate"
#
# 0.048*"student" + 0.044*"school" + 0.029*"education" + 0.027*"charter_school" + 0.013*"child" + 0.012*"parent" + 0.012*"budget" + 0.008*"teacher" + 0.008*"public" + 0.008*"choice"
#
# 0.025*"war" + 0.019*"libya" + 0.017*"president" + 0.016*"israel" + 0.011*"military" + 0.011*"iran" + 0.010*"power" + 0.009*"united_state" + 0.009*"resolution" + 0.007*"u"
#
# 0.034*"energy" + 0.027*"oil" + 0.016*"pipeline" + 0.011*"keystone_pipeline" + 0.008*"administration" + 0.008*"canada" + 0.007*"drill" + 0.007*"production" + 0.007*"price" + 0.007*"natural_gas"
#
# 0.041*"woman" + 0.038*"child" + 0.012*"family" + 0.006*"mother" + 0.006*"life" + 0.006*"parent" + 0.006*"poverty" + 0.006*"republican" + 0.005*"domestic_violence" + 0.005*"abuse"
#
# 0.082*"regulation" + 0.019*"regulatory" + 0.019*"page_line" + 0.016*"follow_page" + 0.013*"cost" + 0.012*"strike" + 0.012*"agency" + 0.009*"new" + 0.009*"line_insert" + 0.009*"line_strike"
#
# 0.077*"medicare" + 0.032*"senior" + 0.021*"plan" + 0.011*"social_security" + 0.010*"ipab" + 0.010*"physician" + 0.010*"doctor" + 0.010*"save" + 0.009*"care" + 0.008*"cut"
#
# 0.010*"research" + 0.007*"afghanistan" + 0.007*"security" + 0.006*"technology" + 0.006*"support" + 0.005*"military" + 0.005*"important" + 0.004*"company" + 0.004*"ensure" + 0.004*"troop"
